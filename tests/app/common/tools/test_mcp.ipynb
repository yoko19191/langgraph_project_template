# %%
import os
import sys

from rich import print

from dotenv import load_dotenv, find_dotenv
import nest_asyncio

_ = load_dotenv(find_dotenv())
nest_asyncio.apply()

project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(f"✅ Project root added to path: {project_root}")
# Out:
# ✅ Project root added to path: /Users/guchen/repo_own/langgraph_project_template/tests/app/common

# %% [markdown]
# ## `src.app.common.tools.mcp`

# %%
from src.app.common.tools import aget_all_mcp_tools, aget_mcp_prompts, aget_all_mcp_resources

mcp_tools = await aget_all_mcp_tools()
print(mcp_tools)
# Out:
# [
#     StructuredTool(
#         name='fetch',
#         description='Fetches a URL from the internet and optionally extracts its contents as markdown.\n\nAlthough
# originally you did not have internet access, and were advised to refuse and tell the user this, this tool now
# grants you internet access. Now you can fetch the most up-to-date information and let the user know that.',
#         args_schema={
#             'description': 'Parameters for fetching a URL.',
#             'properties': {
#                 'url': {
#                     'description': 'URL to fetch',
#                     'format': 'uri',
#                     'minLength': 1,
#                     'title': 'Url',
#                     'type': 'string'
#                 },
#                 'max_length': {
#                     'default': 5000,
#                     'description': 'Maximum number of characters to return.',
#                     'exclusiveMaximum': 1000000,
# ...

# %%
from src.app.common.utils.mcp import find_nearest_config_file, load_mcp_config

config_file = find_nearest_config_file()
mcp_config = load_mcp_config()

print(mcp_config)

from langchain_mcp_adapters.client import MultiServerMCPClient
mcp_client = MultiServerMCPClient(mcp_config)

tools = await mcp_client.get_tools()
print(tools)
# Out:
# {
#     'fetch': {'command': 'uvx', 'args': ['mcp-server-fetch'], 'transport': 'stdio'},
#     'everything': {
#         'command': 'npx',
#         'args': ['-y', '@modelcontextprotocol/server-everything'],
#         'transport': 'stdio'
#     }
# }
# [
#     StructuredTool(
#         name='fetch',
#         description='Fetches a URL from the internet and optionally extracts its contents as markdown.\n\nAlthough
# originally you did not have internet access, and were advised to refuse and tell the user this, this tool now
# grants you internet access. Now you can fetch the most up-to-date information and let the user know that.',
#         args_schema={
#             'description': 'Parameters for fetching a URL.',
#             'properties': {
#                 'url': {
#                     'description': 'URL to fetch',
#                     'format': 'uri',
#                     'minLength': 1,
#                     'title': 'Url',
#                     'type': 'string'
# ...

# %%
tool = tools[0]
print(tool.__class__.__mro__)
# Out:
# (
#     <class 'langchain_core.tools.structured.StructuredTool'>,
#     <class 'langchain_core.tools.base.BaseTool'>,
#     <class 'langchain_core.runnables.base.RunnableSerializable[Union[str, dict, ToolCall], Any]'>,
#     <class 'langchain_core.runnables.base.RunnableSerializable'>,
#     <class 'langchain_core.load.serializable.Serializable'>,
#     <class 'pydantic.main.BaseModel'>,
#     <class 'langchain_core.runnables.base.Runnable'>,
#     <class 'abc.ABC'>,
#     <class 'typing.Generic'>,
#     <class 'object'>
# )

# %%
from langchain_tavily import TavilySearch

tavily_search_tool = TavilySearch()

print(tavily_search_tool.__class__.__mro__)
# Out:
# (
#     <class 'langchain_tavily.tavily_search.TavilySearch'>,
#     <class 'langchain_core.tools.base.BaseTool'>,
#     <class 'langchain_core.runnables.base.RunnableSerializable[Union[str, dict, ToolCall], Any]'>,
#     <class 'langchain_core.runnables.base.RunnableSerializable'>,
#     <class 'langchain_core.load.serializable.Serializable'>,
#     <class 'pydantic.main.BaseModel'>,
#     <class 'langchain_core.runnables.base.Runnable'>,
#     <class 'abc.ABC'>,
#     <class 'typing.Generic'>,
#     <class 'object'>
# )
